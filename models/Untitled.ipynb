# %%
import pandas as pd

# %%
df=pd.read_json('file.json')

# %%
df.head()
# Out:
#                                        architectures  \
# 0             [{'name': 'amd64', 'label': 'x86-64'}]
# 1             [{'name': 'amd64', 'label': 'x86-64'}]
# 2             [{'name': 'amd64', 'label': 'x86-64'}]
# 3             [{'name': 'amd64', 'label': 'x86-64'}]
# 4  [{'name': 'amd64', 'label': 'x86-64'}, {'name'...
#
#                                           categories certification_status  \
# 0  [{'name': 'languages', 'label': 'Programming L...            certified
# 1       [{'name': 'database', 'label': 'Databases'}]            certified
# 2  [{'name': 'storage', 'label': 'Storage'}, {'na...        not_certified
# 3  [{'name': 'application_framework', 'label': 'A...            certified
# 4       [{'name': 'database', 'label': 'Databases'}]        not_certified
#
#                   created_at filter_type id  \
# 0 2017-04-18 01:43:57.982474       store
# 1 2017-08-14 17:33:32.464356       store
# 2 2016-06-16 00:00:00.000000    official
# ...

# %%
df.describe()
# Out:
#        popularity    star_count
# count        25.0     25.000000
# mean          0.0   3116.800000
# std           0.0   3337.087203
# min           0.0      0.000000
# 25%           0.0    374.000000
# 50%           0.0   1522.000000
# 75%           0.0   5640.000000
# max           0.0  10980.000000

# %%
df['filter_type'].value_counts()
# Out:
# official    19
# store        6
# Name: filter_type, dtype: int64
